# %% [markdown]
# ### Capstone project name
#
# - <b>Environmental Research Question / Intro & Background:</b>
# 	- Why do we care about this topic? Why is it important?
#     - Cite recent trends to convince a reader who's new to the topic
# - <b>Data:</b>
# 	- Where did you get your data from?
#     - What does it measure?
#     - What caveats does a new audience need to know about your data?
#     	- For e.g. if it only covers certain pollutant types, it might not measure XYZ "edge cases"
# - <b>Exploratory Data Analysis:</b>
# 	- Give new audiences a "lay of the land" / What is the "shape" of your data?
#     - Imagine you're standing at a viewpoint of a town
#     	- What are the important landmarks?
#         - Is this a rural or urban town?
#         - Coastal, mountains, grassland?
#         - Is it 70% agriculture or 20% agriculture?
# - <b>Final Analysis and Visualizations:</b>
# 	- What visualizations answer your initial Environmental Research Questions?
# - <b>Ethical Considerations / Limitations:</b>
# 	- What caveats should a new audience know about your capstone?
#     - We've formed some opinions about your capstone - what opinions should we NOT form?
#     - I.e. "Take my capstone with these pinches of salt"
# - <b>Big picture takeaways / Future directions:</b>
# 	- Summarize your project in the 5 most important sentences
# -  <b>Notes for reproducibility:</b>
# 	- Write a step-by-step summarizing what I did to produce this project

# %%
library(tidyverse)
#install.packages('readxl')
library(readxl)
cs20 <- read.csv('data/co-est2020-alldata.csv')
hpi <- read_excel('data/hpi_at_bdl_county.xlsx',skip=6)
head(cs20)
head(hpi)
# Out:
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.4     ✔ readr     2.1.5
# ✔ forcats   1.0.0     ✔ stringr   1.5.1
# ✔ ggplot2   3.5.2     ✔ tibble    3.3.0
# ✔ lubridate 1.9.4     ✔ tidyr     1.3.1
# ✔ purrr     1.1.0
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
#   SUMLEV REGION DIVISION STATE COUNTY STNAME  CTYNAME        CENSUS2010POP
# 1 40     3      6        1     0      Alabama Alabama        4779736
# 2 50     3      6        1     1      Alabama Autauga County 54571
# 3 50     3      6        1     3      Alabama Baldwin County 182265
# 4 50     3      6        1     5      Alabama Barbour County 27457
# 5 50     3      6        1     7      Alabama Bibb County    22915
# ...

# %%
?read_excel
# Out:
# read_excel               package:readxl                R Documentation
#
# s
#
# n:
#
#      Read xls and xlsx files
#
#      ‘read_excel()’ calls ‘excel_format()’ to determine if ‘path’ is
#      xls or xlsx, based on the file extension and the file itself, in
#      that order. Use ‘read_xls()’ and ‘read_xlsx()’ directly if you
#      know better and want to prevent such guessing.
#
# e:
#
#      read_excel(
#        path,
#        sheet = NULL,
#        range = NULL,
#        col_names = TRUE,
#        col_types = NULL,
#        na = "",
#        trim_ws = TRUE,
#        skip = 0,
#        n_max = Inf,
#        guess_max = min(1000, n_max),
#        progress = readxl_progress(),
#        .name_repair = "unique"
#      )
#
#      read_xls(
#        path,
#        sheet = NULL,
#        range = NULL,
#        col_names = TRUE,
#        col_types = NULL,
#        na = "",
#        trim_ws = TRUE,
#        skip = 0,
#        n_max = Inf,
#        guess_max = min(1000, n_max),
# ...
